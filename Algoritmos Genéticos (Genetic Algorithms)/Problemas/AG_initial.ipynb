# %% [markdown]
# ### Bibliotecas necessárias

# %%
#

# %% [markdown]
# Importação das bibliotecas para o codigo

# %%
import random
import string

# %% [markdown]
# **Classe Agent:** Essa classe representa um agente individual no algoritmo genético. Cada agente possui uma string gerada aleatoriamente e um valor de aptidão (fitness) inicializado como -1

# %%
class Agent:
    def __init__(self, length):
        self.string = ''.join(random.choice(alfabeto) for _ in range(length))
        self.fitness = -1
    def __str__(self):
        return ('String: ' + str(self.string) + ' Fitness: ' + str(self.fitness))

# %% [markdown]
# **Variáveis iniciais:** São definidas algumas variáveis iniciais, como a string de destino (in_str), o tamanho da string (in_str_len), o número de agentes na população (populacao) e o número de gerações (geracoes).

# %%
alfabeto = " abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!.,"

in_str = None
in_str_len = None
populacao = 30
geracoes = 1000

# %% [markdown]
# **Função ga()**: Essa função é responsável por executar o algoritmo genético. Ela inicializa a população de agentes, itera sobre as gerações, calcula a aptidão dos agentes, seleciona os melhores agentes, realiza o crossover e a mutação. Se a solução desejada for encontrada (aptidão de pelo menos 10.0), o algoritmo é interrompido.

# %%
def ga():
    agents = init_agents(populacao, in_str_len)
    for geracao in range(geracoes):
        print('Geração: ' + str(geracao))
        agents = fitness(agents)
        agents = selecao(agents)
        agents = crossover(agents)
        agents = mutacao(agents)
        if any(agent.fitness >= 10.0 for agent in agents):
            print('Solução encontrada')
            break

# %% [markdown]
# **Função init_agents()**: Essa função inicializa a população de agentes. Ela cria um número especificado de agentes com strings geradas aleatoriamente.

# %%
def init_agents(populacao, length):
    print(Agent(length) for _ in range(populacao))
    return [Agent(length) for _ in range(populacao)]

# %% [markdown]
# **Função get_fitness()**: Essa função calcula a aptidão (fitness) de uma determinada string em relação à string de destino. Ela compara cada caractere da string de destino com a string atual e atribui pontos para cada caractere correspondente. A aptidão é calculada como a porcentagem de caracteres correspondentes em relação ao comprimento total da string de destino.

# %%
def get_fitness(string, target):
    points = sum(1 for expected, actual in zip(target, string) if expected == actual)
    return ((points*10)/in_str_len)

# %% [markdown]
# **Função fitness()**: Essa função calcula a aptidão de todos os agentes da população. Ela itera sobre os agentes e chama a função get_fitness() para cada um deles.

# %%
def fitness(agents):
    for agent in agents:
        agent.fitness = get_fitness(agent.string, in_str)
    return agents

# %% [markdown]
# **Função selecao()**: Essa função realiza a seleção dos melhores agentes. Ela classifica os agentes com base em sua aptidão (fitness) e seleciona os 20% melhores agentes para continuar na próxima geração.

# %%
def selecao(agents):
    agents = sorted(agents, key=lambda agent: agent.fitness, reverse=True)
    print('\n'.join(map(str, agents)))
    agents = agents[:int(0.2 * len(agents))]
    return agents

# %% [markdown]
# **Função crossover()**: Essa função realiza o crossover dos agentes selecionados. Ela seleciona dois pais aleatórios e cria dois filhos através da troca de partes das strings dos pais. Os filhos resultantes são adicionados à lista de agentes.

# %%
def crossover(agents):
    offspring = []
    for _ in range(int((populacao - len(agents) / 2))):
        pai1 = random.choice(agents)
        pai2 = random.choice(agents)
        filho1 = Agent(in_str_len)
        filho2 = Agent(in_str_len)
        split = random.randint(0, in_str_len)
        filho1.string = pai1.string[0:split] + pai2.string[split:in_str_len]
        filho2.string = pai2.string[0:split] + pai1.string[split:in_str_len]
        offspring.append(filho1)
        offspring.append(filho2)
    agents.extend(offspring)
    return agents

# %% [markdown]
# **Função mutacao()**: Essa função realiza a mutação dos agentes. Ela itera sobre cada agente e, com uma probabilidade de 0,1 para cada caractere da string, realiza a substituição desse caractere por um novo caractere aleatório do alfabeto.

# %%
def mutacao(agents):
    for agent in agents:
        for idx, param in enumerate(agent.string):
            if random.uniform(0.0, 1.0) <= 0.1:
                agent.string = agent.string[0:idx] + random.choice(alfabeto) + agent.string[idx+1:in_str_len]
    return agents

# %% [markdown]
# Bloco if name == 'main': Nesse bloco, é definida a string de destino (in_str) e seu comprimento (in_str_len), e a função ga() é chamada para iniciar o algoritmo genético.

# %%
if __name__ == '__main__':
    in_str = 'Boa tarde, turma de IA!'
    in_str_len = len(in_str)
    ga()
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# String: Boz tarde, tuQBa de IA! Fitness: 8.695652173913043
# String: Boz tarde, tuQBa de IA! Fitness: 8.695652173913043
# String: Bob tardel tuJEa de IA! Fitness: 8.26086956521739
# String: Boa tarde, turza Hn It! Fitness: 8.26086956521739
# String: VCa tarde, tuEwa de IA! Fitness: 8.26086956521739
# String: Boa tardeJ t!Jha de IA! Fitness: 8.26086956521739
# String: Voa tardeU tuEBa de IA! Fitness: 8.26086956521739
# String: Boa taEdee turBa dq IA! Fitness: 8.26086956521739
# String: Boz tardel tuJEa de IA! Fitness: 8.26086956521739
# String: Bo  tardeU tuEBa de IA! Fitness: 8.26086956521739
# String: Vol tarde, tuQBa de IA! Fitness: 8.26086956521739
# String: Boa tardeUGtuEBa de IA! Fitness: 8.26086956521739
# String: B!a tarde,UtulTa de IA! Fitness: 8.26086956521739
# String: Boa tarde,UwulTadde IA! Fitness: 7.826086956521739
# String: Boa tarde,ntuPTY de.IA! Fitness: 7.826086956521739
# String: Bod tarGe,ntu!Ta de IA! Fitness: 7.826086956521739
# String: BoZ tarde, xuQBo de IA! Fitness: 7.826086956521739
# String: Boa Qarde, trJBa deBIA! Fitness: 7.826086956521739
# String: Vya taode, tu!Ta de IA! Fitness: 7.826086956521739
# String: Boa Qarde, tuJBa dtFIA! Fitness: 7.826086956521739
# String: BoB tardel tuJEa ce IA! Fitness: 7.826086956521739
# String: Boz tarde, luQBY de IA! Fitness: 7.826086956521739
# String: Boa marde,ntuPTY de IA! Fitness: 7.826086956521739
# String: Boa Qarde, tuJKa dt IAw Fitness: 7.826086956521739
# String: xoz tarde. tuQBa de IA! Fitness: 7.826086956521739
# String: Boa tardSVUtuEBa de IA! Fitness: 7.826086956521739
# String: Voa tardeU tulTa de PA! Fitness: 7.826086956521739
# String: VCa tardeH tuEBa de IA! Fitness: 7.826086956521739
# String: BoO tarde, tuPBacdj IA! Fitness: 7.826086956521739
# String: BoZ tapdel tuJEa de IA! Fitness: 7.826086956521739
# String: Boz Tardb, tuQBd de IA! Fitness: 7.391304347826087
# String: Boa Qarde, tu Ba pt IAw Fitness: 7.391304347826087
# String: BoZ tardel tuvEa dt IAw Fitness: 7.391304347826087
# String: BoZutarde,UtUlTa de IA! Fitness: 7.391304347826087
# String: Voa yardeU tuEBa Ie IA! Fitness: 7.391304347826087
# String: Boa tardek burQa Hn It! Fitness: 7.391304347826087
# String: roa tarde,ntu!Tm de IW! Fitness: 7.391304347826087
# String: Boahtarde,UtulTa depIA, Fitness: 7.391304347826087
# String: Boa tarde,np,PTY de IA! Fitness: 7.391304347826087
# String: BoactsKde,ntV!ga de IA! Fitness: 6.956521739130435
# String: Bod SarGe,ntuE acde IA! Fitness: 6.956521739130435
# String: Boa tarqxlztuJEa de IAk Fitness: 6.956521739130435
# String: Boa,Qkrde,PtuJBa da IA! Fitness: 6.956521739130435
# String: Boa Qarde, tuJBE dtvIAw Fitness: 6.956521739130435
# String: Bod tarGe,ntuPTY  e IA! Fitness: 6.956521739130435
# String: BoYJtarde,ntuPTY de IAc Fitness: 6.956521739130435
# String: BoO tardk, tuPBacdjFIA! Fitness: 6.956521739130435
# String: Boz tar!e, tuQBaqdZ Ic! Fitness: 6.956521739130435
# String: ErO tarde, tuPBIcdj IA! Fitness: 6.521739130434782
# String: E!a  arde,UtDlTa de IQ! Fitness: 6.521739130434782
# String: Bua tarde,UtDlT  dC IAw Fitness: 6.521739130434782
# String: koO tarde, tuPBacdj ICw Fitness: 6.521739130434782
# String: Voa tardeQnWuPTY de Ig! Fitness: 6.521739130434782
# String: Yoa tarde,ntuPTYAFe IJ! Fitness: 6.521739130434782
# String: ooa Qarde,HtuJka dtHIAw Fitness: 6.521739130434782
# String: LFa tarde,nJB!Te de IA! Fitness: 6.521739130434782
# String: VCa tardPJ t!JhaQde IA! Fitness: 6.521739130434782
# String: aoa tardeU WuBBa Hn IZA Fitness: 6.086956521739131
# Geração: 94
# String: Boa tarde, tuwBa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tuwBa de IA! Fitness: 9.130434782608695
# String: Boa taEdee turBa de IA! Fitness: 8.695652173913043
# String: BoaPtarde, tuwBa de IA! Fitness: 8.695652173913043
# String: Boz tarde, tuQIa de IA! Fitness: 8.695652173913043
# String: Boa tarde, tuwBa dJ IA! Fitness: 8.695652173913043
# String: moa tarde, tuwBa de IA! Fitness: 8.695652173913043
# String: Boa tarde, tuwBa de Iy! Fitness: 8.695652173913043
# String: Poz tarde, tuQBa de IA! Fitness: 8.26086956521739
# String: Boz tardel tuJEa de IA! Fitness: 8.26086956521739
# String: Boz tarde, tDQBa de IA! Fitness: 8.26086956521739
# String: Boi tardE, turza Se IA! Fitness: 8.26086956521739
# String: BCa tardD, tuEwa de IA! Fitness: 8.26086956521739
# String: Voa tardeU tuEBa de IA! Fitness: 8.26086956521739
# String: Boa tarde,.tuwBa de IAP Fitness: 8.26086956521739
# String: Boa tardeJ t!Jha de IA! Fitness: 8.26086956521739
# String: Boz tardM, tuQBa de IA! Fitness: 8.26086956521739
# String: VCa tarde, tuQBa de IA! Fitness: 8.26086956521739
# String: VCa tarde, tuEwa de IA! Fitness: 8.26086956521739
# String: Boa tarde,UtulTozde IA! Fitness: 7.826086956521739
# String: Boz tardes tuQBa deeIA! Fitness: 7.826086956521739
# String: Boa tarde, turzO Hn It! Fitness: 7.826086956521739
# String: Bou taEdee turBa dq IA! Fitness: 7.826086956521739
# String: Boz tardel tuJEa de IAS Fitness: 7.826086956521739
# String: Boa tarde,Utulwa de RO! Fitness: 7.826086956521739
# String: Boz tardeF tuJEa re IA! Fitness: 7.826086956521739
# String: Boa taEdee BurBa dq IA! Fitness: 7.826086956521739
# String: Boa tarde, turza HnyIAd Fitness: 7.826086956521739
# String: Boa tarde, tsrzq Hn IA! Fitness: 7.826086956521739
# String: Bo  tarde, tcQWa ne IA! Fitness: 7.826086956521739
# String: Boz tarveU tuEBa de IA! Fitness: 7.826086956521739
# String: BOD tardei tuQBa de IA! Fitness: 7.826086956521739
# String: Boa taEdee turBI dq IA! Fitness: 7.826086956521739
# String: Woa tardeJ t!Jha de IA! Fitness: 7.826086956521739
# String: Boa tardeJ i!Hha de IA! Fitness: 7.826086956521739
# String: Bod tJrde, tuJEa de IAo Fitness: 7.826086956521739
# String: Boa tardeJ KzJya derIA! Fitness: 7.391304347826087
# String: VCa tarde, tuETy deUIA! Fitness: 7.391304347826087
# String: Voa tardeJ B!Jha de IA! Fitness: 7.391304347826087
# String: VCy tarde, tuEwd de IA! Fitness: 7.391304347826087
# String: Boa tardeX turzG Hn It! Fitness: 7.391304347826087
# String: Bopbtardey tuJEa de IU! Fitness: 7.391304347826087
# String: Boa taEdee ttrBa dq cA! Fitness: 7.391304347826087
# String: BozXtardeJ t!Jha de IA! Fitness: 7.391304347826087
# String: BKz aarde, tuEwa dl IA! Fitness: 7.391304347826087
# String: BoaztardF, tuwBawdebIA! Fitness: 7.391304347826087
# String: Bo  taSdeU tuEBa de I.! Fitness: 7.391304347826087
# String: Voa tardeJ luEeR de IA! Fitness: 7.391304347826087
# String: Voa tard!U tuEBa dj IA! Fitness: 7.391304347826087
# String: Voa tardeU tuEBY dM IA! Fitness: 7.391304347826087
# String: VC! tardeX tnEwa de IA! Fitness: 6.956521739130435
# String: Voa taKdeC tuEBO de IJ! Fitness: 6.956521739130435
# String: BB  tardMU GuEBa de IA! Fitness: 6.956521739130435
# String: Ooz taEde, tuQBa ye IF! Fitness: 6.956521739130435
# String: Bab Zardel tuJEaIdP IA! Fitness: 6.521739130434782
# String: Joz tardeO turza Hn IuG Fitness: 6.521739130434782
# String: Boz zGrdel tuJha HC It! Fitness: 6.086956521739131
# String: VCl tarde, dbEwa ae IAQ Fitness: 6.086956521739131
# String: Bob tardWJ Y!Jha dR IAj Fitness: 6.086956521739131
# String: BxahtaAleJ t!Jha dy It! Fitness: 5.6521739130434785
# Geração: 95
# String: Boa tarde, tuwBa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tubBa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tuQIa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tuwBa de IA! Fitness: 9.130434782608695
# String: Boa tarSe, tuwBa de IA! Fitness: 8.695652173913043
# String: Boa taEdee turca de IA! Fitness: 8.695652173913043
# String: BoaPtardN, tuwBa de IA! Fitness: 8.26086956521739
# String: moa tarde, tuwBa de IAW Fitness: 8.26086956521739
# String: Boa tarde,EtuwBa de Iy! Fitness: 8.26086956521739
# String: Boi tarde, tuQBa de IAb Fitness: 8.26086956521739
# String: Boa tarde,HtuwBa dJ IA! Fitness: 8.26086956521739
# String: Boa tarde, txwBa deDIA! Fitness: 8.26086956521739
# String: BCa tarde, tuwBaKde IA! Fitness: 8.26086956521739
# String: Boz tarde, tuwBa de Iy! Fitness: 8.26086956521739
# String: BoXPtarde, tuwBa de IA! Fitness: 8.26086956521739
# String: Poz tarde, tuQBa de IA! Fitness: 8.26086956521739
# String: Boa tarde, tuwBa de Vy! Fitness: 8.26086956521739
# String: Boa tsrde, tuwAa dy IA! Fitness: 8.26086956521739
# String: Boa tarde,wtuwBa dY IA! Fitness: 8.26086956521739
# String: Boa tajde, tuwBa dR IA! Fitness: 8.26086956521739
# String: Boa taEdee turB  xe IA! Fitness: 7.826086956521739
# String: Boz tarde, tuQkkSde IA! Fitness: 7.826086956521739
# String: BoU tarzel tuJEa de IA! Fitness: 7.826086956521739
# String: BoaPtaodQ, tuQBa de IA! Fitness: 7.826086956521739
# String: Poz tardE, turza Se IA! Fitness: 7.826086956521739
# String: PoX tarde, LuQBa de IA! Fitness: 7.826086956521739
# String: Boz taNde, tD.Ba de IA! Fitness: 7.826086956521739
# String: Coz takde, tuQBa de IA! Fitness: 7.826086956521739
# String: Poz tarde, tuQBa dX IA! Fitness: 7.826086956521739
# String: Boa takde, tuwBa dJ Iy! Fitness: 7.826086956521739
# String: Boz tardelbtuJEa de IA! Fitness: 7.826086956521739
# String: Boa tarde, NuwBaadJ IA! Fitness: 7.826086956521739
# String: BoY taEoee turBa de IA! Fitness: 7.826086956521739
# String: Yoa tarde, buwWa Fe IA! Fitness: 7.826086956521739
# String: Boa qarde, tuwBO du IA! Fitness: 7.826086956521739
# String: xoz tarde, tuQIa de Iy! Fitness: 7.826086956521739
# String: BoaKtarCe,AtuwBa dJ IA! Fitness: 7.391304347826087
# String: Bo  taYde, tDQBa deIIA! Fitness: 7.391304347826087
# String: Pozhtardq, tuQBa de IA! Fitness: 7.391304347826087
# String: yoi tardE, turgaMbe IA! Fitness: 7.391304347826087
# String: BUz tarde, tDQBa de jA! Fitness: 7.391304347826087
# String: Boa t,rdePctuwBa dejIA! Fitness: 7.391304347826087
# String: BoaPtardeN tuwBaTde IAk Fitness: 7.391304347826087
# String: Boz tarde, tmQIa de Izx Fitness: 7.391304347826087
# String: F!K tarde, tuQBaUde IA! Fitness: 7.391304347826087
# String: Boa taEdEe tudBa de IAd Fitness: 7.391304347826087
# String: Boa tarde,xtFwBabde Iy! Fitness: 7.391304347826087
# String: Boa taEdRe turBFwde IA! Fitness: 7.391304347826087
# String: BoUDtarde, tuwBa de Iyk Fitness: 7.391304347826087
# String: BsaPtardY,YtuwBa de IX! Fitness: 6.956521739130435
# String: BoXLtarde, buwBa dY I ! Fitness: 6.956521739130435
# String: !oz tarde, tDQBa de IXn Fitness: 6.956521739130435
# String: Boa tJrdeP tuwBa d! jy! Fitness: 6.956521739130435
# String: BozWtardE, tuQIa de sc! Fitness: 6.956521739130435
# String: Boi wardE, tDrzaVSe IA! Fitness: 6.956521739130435
# String: Boi tariE, vurzatSo IA! Fitness: 6.521739130434782
# String: Phz tardel tuJEaLze IA! Fitness: 6.521739130434782
# String: Boa aaEdeeFturBa de kVA Fitness: 6.521739130434782
# String: Poz Cardu, tKQBapde ,A! Fitness: 6.086956521739131
# String: Kvz tarde, DDQBa dv IAB Fitness: 6.086956521739131
# Geração: 96
# String: Boa tarde, tubBa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tuRBa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tubBa de IA! Fitness: 9.130434782608695
# String: Boa tarde, tubBa de IA! Fitness: 9.130434782608695
# String: Boa taEdee turca de IA! Fitness: 8.695652173913043
# String: Boa tarde, tubBa ne IA! Fitness: 8.695652173913043
# String: Boa tarde, tuwBa de IAW Fitness: 8.695652173913043
# String: Boa tarCe, tuQIa de IA! Fitness: 8.695652173913043
# String: Boa tarde,qtuwBa de IA! Fitness: 8.695652173913043
# String: Bta Zarde, tuwBa de IA! Fitness: 8.26086956521739
# String: Boa tarde, tuQIa de IYY Fitness: 8.26086956521739
# String: Boa uarde, tnwBa de IA! Fitness: 8.26086956521739
# String: Boajtarde, tubBa de IV! Fitness: 8.26086956521739
# String: Boa tarde,EtuwBa de Iy! Fitness: 8.26086956521739
# String: BoaWtarde,EtuwBa de IA! Fitness: 8.26086956521739
# String: Boa tarde, fuwBa de IAb Fitness: 8.26086956521739
# String: Boa xar,e, tuIIa de IA! Fitness: 8.26086956521739
# String: Boa tarSe, tueBa de I.! Fitness: 8.26086956521739
# String: Boa yarce, tuwBa de IA! Fitness: 8.26086956521739
# String: Boa taEdee turca de IAW Fitness: 8.26086956521739
# String: Boa ta de, tuQPaLde IA! Fitness: 8.26086956521739
# String: Boa tarde, txwBa HeDIA! Fitness: 7.826086956521739
# String: B!a tarde, tuQMa Qe IAb Fitness: 7.826086956521739
# String: Boa tirde, txwBa deDIA! Fitness: 7.826086956521739
# String: BoattaEiee turca de IA! Fitness: 7.826086956521739
# String: moa tarde,DiuwBa de IA! Fitness: 7.826086956521739
# String: Boa tarde,EtuwBa dr IAb Fitness: 7.826086956521739
# String: Boa tardg, tuwBa Ce IAW Fitness: 7.826086956521739
# String: Boa.tarde, tuwBa deKIf! Fitness: 7.826086956521739
# String: Boaitarde, CuwBa de IX! Fitness: 7.826086956521739
# String: Boa taGde, tuwBaWde IAt Fitness: 7.826086956521739
# String: moaStarde, tuwBa de IsW Fitness: 7.391304347826087
# String: Boa tarde,EgXwBa de Iy! Fitness: 7.391304347826087
# String: Bow Zarde, tuQB  de IAb Fitness: 7.391304347826087
# String: Boi tarke,It,wBa de IA! Fitness: 7.391304347826087
# String: BVi taHde, tu,Ba de Iy! Fitness: 7.391304347826087
# String: boaPtaBdN, tuwBa de IA! Fitness: 7.391304347826087
# String: moaGtaXde, tuwBw de IA! Fitness: 7.391304347826087
# String: Boi taYde, tuQBa de ZAW Fitness: 7.391304347826087
# String: moa tardegTtuwBa de Ix! Fitness: 7.391304347826087
# String: aoa tardEF tuwBa de Iy! Fitness: 7.391304347826087
# String: Boi BarBe, tuQBa de Ij! Fitness: 7.391304347826087
# String: Boa ZardS,HtuwBa dv IA! Fitness: 7.391304347826087
# String: BoaGtaEdeW turcYPde IA! Fitness: 7.391304347826087
# String: Boaqtarde,HtugBa dJdIA! Fitness: 7.391304347826087
# String: Bga tarde, tubBF Xe IAf Fitness: 7.391304347826087
# String: BoaMtaEdOe turca de AA! Fitness: 7.391304347826087
# String: moa tarde, tuwBa ve VAt Fitness: 7.391304347826087
# String: Boa tarne, JulBg dFEIA! Fitness: 6.956521739130435
# String: BoaPxardN, tuwBa je IAn Fitness: 6.956521739130435
# String: BZa sfrde,HtuwBa dy IA! Fitness: 6.956521739130435
# String: Boa taEdeeyLurca dwpIA! Fitness: 6.956521739130435
# String: aoa taSSe, tuwBy de IAW Fitness: 6.956521739130435
# String: Boa tardw,HtuwBa,dJ lA! Fitness: 6.956521739130435
# String: BoZptaree, tuQIaJde SA! Fitness: 6.956521739130435
# String: BoaPtawUN, tuwBa Vk IA! Fitness: 6.521739130434782
# String: Bri tkrde, tuQBa dw Jy! Fitness: 6.521739130434782
# String: BXa karde, txwBa dIDLA! Fitness: 6.521739130434782
# String: BVI tadde,EtuwBf de IIb Fitness: 6.086956521739131
# String: jop LaYde, tUwBa de Iib Fitness: 6.086956521739131
# Geração: 97
# String: Boa tarde, tuQIa de IA! Fitness: 9.130434782608695
# String: Boa tardee turca de IA! Fitness: 9.130434782608695
# String: Boa tarde, tubBa de IA! Fitness: 9.130434782608695
# String: Boa tarCe, tuQIa de IA! Fitness: 8.695652173913043
# String: Boa tarde, eulBa de IA! Fitness: 8.695652173913043
# String: Boa tarde, tutBaode IA! Fitness: 8.695652173913043
# String: Eoa tarde, tuQIa de IA! Fitness: 8.695652173913043
# String: Boa tarde, tqQIa de IA! Fitness: 8.695652173913043
# String: BoC tarde, tubBa de IA! Fitness: 8.695652173913043
# String: Boa dardi, tubBa de IA! Fitness: 8.26086956521739
# String: BoaJtaEdeS turca de IA! Fitness: 8.26086956521739
# String: Boa tarde, tubBadne IA! Fitness: 8.26086956521739
# String: Boa tnrde,qtuwBa de IA! Fitness: 8.26086956521739
# String: Boa.tarde, tubBa Oe IA! Fitness: 8.26086956521739
# String: Bov tarde, tubBa,de IA! Fitness: 8.26086956521739
# String: Boa tarde, tubBa !e sA! Fitness: 8.26086956521739
# String: Bfa tarde, tuwBa de Im! Fitness: 8.26086956521739
# String: BoaktarCe, tuQIa de IA! Fitness: 8.26086956521739
# String: Boa tarde, tuR,a de SAt Fitness: 8.26086956521739
# String: Boa tarde, tnwBa de iA! Fitness: 8.26086956521739
# String: Boa tarCef tuQAa de IA! Fitness: 8.26086956521739
# String: Boq tlrde, tuRBa de IAK Fitness: 7.826086956521739
# String: Boa tarCe, kuQIa de IF! Fitness: 7.826086956521739
# String: Boa tarde, tuQIa du IYY Fitness: 7.826086956521739
# String: Boa uYrde, tnwBa de IA! Fitness: 7.826086956521739
# String: Boa tarCe, tuQIa de sAW Fitness: 7.826086956521739
# String: Boa torze, tuwBa De IA! Fitness: 7.826086956521739
# String: Poa tarde, MuRBa de IM! Fitness: 7.826086956521739
# String: Boa tarie, tSBBa ne IA! Fitness: 7.826086956521739
# String: Boa tarde,WtuQIa de IYK Fitness: 7.826086956521739
# String: Boa taEQe, tuwBa de IAW Fitness: 7.826086956521739
# String: BoK tarCe, tuRBa Re IA! Fitness: 7.826086956521739
# String: BoK tardNF tubBa de IA! Fitness: 7.826086956521739
# String: Boa tarCe, tuQIa de PM! Fitness: 7.826086956521739
# String: Boa tarde, DuQIacde YA! Fitness: 7.826086956521739
# String: ,oa tarde, tubBa de IoW Fitness: 7.826086956521739
# String: Boa Sarde,qXubBa de IA! Fitness: 7.826086956521739
# String: Bta Zaree, tubBa de IA! Fitness: 7.826086956521739
# String: BoaXtardu, tukBa je IA! Fitness: 7.826086956521739
# String: Boadtarde, TuZBa de IA, Fitness: 7.826086956521739
# String: Boa tarZe, tuwB,.de IA! Fitness: 7.826086956521739
# String: BoN taEder turcD de IA! Fitness: 7.826086956521739
# String: Boa sarde, tumBq de IU! Fitness: 7.826086956521739
# String: Boa tarde,stuwBA de IAW Fitness: 7.826086956521739
# String: Boa tarde, kjbUa ne IA! Fitness: 7.826086956521739
# String: Boa !AQde, tub,a deNIA! Fitness: 7.391304347826087
# String: Boa taxdd, JuVBa de IAW Fitness: 7.391304347826087
# String: Boa farde, SnwBa de IAW Fitness: 7.391304347826087
# String: BoZ tarde, tgwIa de IWW Fitness: 7.391304347826087
# String: Boa tHrdD, tuRBa de IYY Fitness: 7.391304347826087
# String: Boa tafde, OuwBg de QA! Fitness: 7.391304347826087
# String: BoH uarde, DSbBa de IA! Fitness: 7.391304347826087
# String: Boa tardrC tuwBa d  IAW Fitness: 7.391304347826087
# String: Bta Zarde, tubBa nePIA! Fitness: 7.391304347826087
# String: Boa taWdx, tubBZ Ae IA! Fitness: 7.391304347826087
# String: Bba Iarde, tubBJRde Ij! Fitness: 6.956521739130435
# String: B a uarde, tnwBa de IYY Fitness: 6.956521739130435
# String: Boa tarCe,atnQIa de IYY Fitness: 6.956521739130435
# String: BoaRtArde, tubBa le IzS Fitness: 6.956521739130435
# String: Tta Zarde,atuwBa dV IA, Fitness: 6.521739130434782
# Geração: 98
# String: Boa tarden turla de IA! Fitness: 9.130434782608695
# String: Boa tarde, tuQIa de IA! Fitness: 9.130434782608695
# String: Boa tardN, tuQIa de IA! Fitness: 8.695652173913043
# String: Boa tardee turc! de IA! Fitness: 8.695652173913043
# String: Boa tarde, UubBa de IA! Fitness: 8.695652173913043
# String: Boa tarde, tutBaode IA! Fitness: 8.695652173913043
# String: Boa tardee Nurca de IA! Fitness: 8.695652173913043
# String: BoaDtarde, YulBa de IA! Fitness: 8.26086956521739
# String: BoK tarde, tutBaode IA! Fitness: 8.26086956521739
# String: Boa tzrse, tuQaa de IA! Fitness: 8.26086956521739
# String: Boa tarde, tutBaodS IA! Fitness: 8.26086956521739
# String: Boa tardeeeturca de IB! Fitness: 8.26086956521739
# String: Boa tardG, tubBa,de IA! Fitness: 8.26086956521739
# String: Boa ta,de, eulBa de IA! Fitness: 8.26086956521739
# String: Boa tarde, eilBa de IA! Fitness: 8.26086956521739
# String: Boa tardE, tubBN de IA! Fitness: 8.26086956521739
# String: .oC tarde, tubBa de IA! Fitness: 8.26086956521739
# String: BoaltarCe, tuQIa de IA! Fitness: 8.26086956521739
# String: Boa taUde, tuQIa de IG! Fitness: 8.26086956521739
# String: BoaItardee turck de IA! Fitness: 8.26086956521739
# String: Eoa tarfe, tuQIa deqIA! Fitness: 7.826086956521739
# String: zoCwtarde, tubBa de IA! Fitness: 7.826086956521739
# String: BoaJtaEdeS curca de IA! Fitness: 7.826086956521739
# String: BoaJtaEdeS curca de IA! Fitness: 7.826086956521739
# String: BoH tarde,rtutBaode IA! Fitness: 7.826086956521739
# String: Boa dardi, tubBa de IAD Fitness: 7.826086956521739
# String: BoC tarde, tusBaedd IA! Fitness: 7.826086956521739
# String: Boa XDrCe, tuQIa de IA! Fitness: 7.826086956521739
# String: Boa tardeN tubBadYe IA! Fitness: 7.826086956521739
# String: BoaZtarXMe turca de IA! Fitness: 7.826086956521739
# String: Bpa tarde, tubBadbe IA! Fitness: 7.826086956521739
# String: joa dardi, tubBa de IA! Fitness: 7.826086956521739
# String: BoR tarde, eulBa de  A! Fitness: 7.826086956521739
# String: toa tardee tubB! de IA! Fitness: 7.826086956521739
# String: BoY Garde, tuQIa Pe IA! Fitness: 7.826086956521739
# String: Boa tarde, tqQIa.Me IA! Fitness: 7.826086956521739
# String: BoaJtaEdTS turca de IA! Fitness: 7.826086956521739
# String: Boa tarCe, tuJIu Ze IA! Fitness: 7.826086956521739
# String: Boa tarde, tqQIaidemIA! Fitness: 7.826086956521739
# String: Boa tarCjE tuQIa !e IA! Fitness: 7.391304347826087
# String: Boa tCrCeU tTQIa de IA! Fitness: 7.391304347826087
# String: BoavtaEdeS turca de ICA Fitness: 7.391304347826087
# String: BIa tarde, eulBadne IA! Fitness: 7.391304347826087
# String: U!a tarde, tuQIaFde IAs Fitness: 7.391304347826087
# String: Boa tardU, tubBadge,IA! Fitness: 7.391304347826087
# String: Boa dardi, Murca Ae IK! Fitness: 7.391304347826087
# String: BoR tarde, rutaaode lA! Fitness: 7.391304347826087
# String: Boa mardK,ctqQIa de IA! Fitness: 7.391304347826087
# String: Boa garte, tqQIs dO IA! Fitness: 6.956521739130435
# String: roa turde, tobBadne IA! Fitness: 6.956521739130435
# String: BNa dardi,ftubBa de Ig! Fitness: 6.956521739130435
# String: Bqa tarCe, gTuIa de In! Fitness: 6.956521739130435
# String: goa dardi, tubfp decIA! Fitness: 6.956521739130435
# String: Ooa tarde, tubBadne eAY Fitness: 6.956521739130435
# String: Boa tarde,mtubBa deez,l Fitness: 6.956521739130435
# String: Boa daHdi, tGbBa deJIAl Fitness: 6.521739130434782
# String: Uoa Uarke,DtubBadne IA! Fitness: 6.521739130434782
# String: BoaJpaEdeS turcL He IAs Fitness: 6.521739130434782
# String: woaJtMEdUS turcW de IA! Fitness: 6.521739130434782
# String: Boa dardi, tAbBlcdR lA! Fitness: 6.086956521739131
# Geração: 99
# String: Boa tardef turla de IA! Fitness: 9.130434782608695
# String: Boa tarde, Uubma de IA! Fitness: 9.130434782608695
# String: Boa tarde, UubBa de IA! Fitness: 8.695652173913043
# String: Boa darden turla de IA! Fitness: 8.695652173913043
# String: Boa tarde, YulBa de IA! Fitness: 8.695652173913043
# String: Boa tarde, tuQIa dm IA! Fitness: 8.695652173913043
# String: Boa tardN, tuQIa de IA! Fitness: 8.695652173913043
# String: Boa tarde, NuxZa de IA! Fitness: 8.695652173913043
# String: BoaQtarde, tuQIaXde IA! Fitness: 8.26086956521739
# String: Boaotarde, tutBaode IA! Fitness: 8.26086956521739
# String: Boa Cardee Nurca de IA! Fitness: 8.26086956521739
# String: Bo, tardee turc! de IA! Fitness: 8.26086956521739
# String: Boa tarden turla deDRA! Fitness: 8.26086956521739
# String: BoK tarde, tKQIa de IA! Fitness: 8.26086956521739
# String: Boa PardenKturla de IA! Fitness: 8.26086956521739
# String: Boa tardN, tuQIa dB IA! Fitness: 8.26086956521739
# String: Boa tYrdR, tuQIa de IA! Fitness: 8.26086956521739
# String: BoaDtarden tJrla de IA! Fitness: 8.26086956521739
# String: Boa tarde, YulBa dC IA! Fitness: 8.26086956521739
# String: BoaRtarde, tutBaode IA! Fitness: 8.26086956521739
# String: Boa tardeF tutBaode IA! Fitness: 8.26086956521739
# String: Boa tarde, tutBaodS IA! Fitness: 8.26086956521739
# String: goaDtarde, YulBa de IA! Fitness: 7.826086956521739
# String: BoK tarde, tutBaode IAD Fitness: 7.826086956521739
# String: Bza tarde, tuDBaodS IA! Fitness: 7.826086956521739
# String: Boa tarFeeeturca de IB! Fitness: 7.826086956521739
# String: BoY Farde, UubBa de IA! Fitness: 7.826086956521739
# String: Joa tardN, tutBaode IA! Fitness: 7.826086956521739
# String: BoE tarsP, tuQaa de IA! Fitness: 7.826086956521739
# String: PiI tarde, tuQIa de IA! Fitness: 7.826086956521739
# String: Boa bardF, tutBaode IA! Fitness: 7.826086956521739
# String: Boa tarde, tutBaonS IA! Fitness: 7.826086956521739
# String: Bom Vardee turc! de IA! Fitness: 7.826086956521739
# String: Baa tarden tKrla de QA! Fitness: 7.826086956521739
# String: Boa taAden tRrla depIA! Fitness: 7.826086956521739
# String: Bpa tardD, YulBa de IA! Fitness: 7.826086956521739
# String: BoK tarde, tutBaode IAn Fitness: 7.826086956521739
# String: Boj tardeeLtuHIa de IA! Fitness: 7.826086956521739
# String: Boa tardN, qFQID de IA! Fitness: 7.391304347826087
# String: Boa tzrse, tuQaaRdV IA! Fitness: 7.391304347826087
# String: BoK tIrde, tutBaode TA! Fitness: 7.391304347826087
# String: Boa tzrze, tuQaa do IAv Fitness: 7.391304347826087
# String: BoaDtarSeI YuHta de IA! Fitness: 7.391304347826087
# String: Boa tcrdeieturca de WB! Fitness: 7.391304347826087
# String: Boa tardYa !urc!qde IA! Fitness: 7.391304347826087
# String: Boa tardeeequrcD de IB! Fitness: 7.391304347826087
# String: BoaCtarden turly beYIA! Fitness: 7.391304347826087
# String: BoK tirde, tutBaodV IA! Fitness: 7.391304347826087
# String: BoaDtaTde,qYulBa de IA! Fitness: 7.391304347826087
# String: Boa tWryee NurcaIde IA! Fitness: 7.391304347826087
# String: Bea tareee Nurca dL IA! Fitness: 7.391304347826087
# String: Boe tarde, UubBaO.e IA! Fitness: 7.391304347826087
# String: BoaFtzrse, tuQaa de IY! Fitness: 7.391304347826087
# String: Boa tzrse, tLQLa de IAg Fitness: 7.391304347826087
# String: Boi xcrdee turc! dE IA! Fitness: 6.956521739130435
# String: Boa tardee NurcaUQeVIAs Fitness: 6.956521739130435
# String: Boa tzrda, tuQda De IgG Fitness: 6.956521739130435
# String: Boa tarde,CtBtBaodS zA! Fitness: 6.956521739130435
# String: BoaDCaOdeeeturca de IV! Fitness: 6.956521739130435
# String: Boa tarnxeeturcahdc Iw! Fitness: 6.521739130434782
# Geração: 100
# String: Boaotarde, tutma de IA! Fitness: 9.130434782608695
# String: Boa tarden turla de IA! Fitness: 9.130434782608695
# String: Boa tarde, Uubma de IAS Fitness: 8.695652173913043
# String: Boa tarde, YulBa de IA! Fitness: 8.695652173913043
# String: Boa tarde, Yulqa de IA! Fitness: 8.695652173913043
# String: Boa tardef turla de Ic! Fitness: 8.695652173913043
# String: Boaotarde, Uubma de IA! Fitness: 8.695652173913043
# String: Boa tarde, tutBaode IA! Fitness: 8.695652173913043
# String: Boa tarde, Uu,Ba de IA! Fitness: 8.695652173913043
# String: Boa darden turla de IAY Fitness: 8.26086956521739
# String: BoaQtarde, tuQIaXde IA! Fitness: 8.26086956521739
# String: Bo, tardee turc! de IA! Fitness: 8.26086956521739
# String: Boa tarde, jubBa Re IA! Fitness: 8.26086956521739
# String: BoaQtarde, Uubma we IA! Fitness: 8.26086956521739
# String: Bra darden turca de IA! Fitness: 8.26086956521739
# String: BoaQtardeE turla dt IA! Fitness: 8.26086956521739
# String: Boaotarde, tutBarde IA! Fitness: 8.26086956521739
# String: Boa tarde, UHbBa de IA! Fitness: 8.26086956521739
# String: BoaZtardN,Qturla de IA! Fitness: 8.26086956521739
# String: Bo, tardee turc! de IA! Fitness: 8.26086956521739
# String: Bma tarde, UuxZa de IA! Fitness: 8.26086956521739
# String: Bo, tardee turc! de IA! Fitness: 8.26086956521739
# String: Bxaftardef lurla de IA! Fitness: 7.826086956521739
# String: Boa tarde, YulBa dm Ip! Fitness: 7.826086956521739
# String: Boavtaede, tuQIa dL IA! Fitness: 7.826086956521739
# String: Boa Aarde, NuxZa de zA! Fitness: 7.826086956521739
# String: Boa taWde, YulBa de IAh Fitness: 7.826086956521739
# String: Boaotarde, cutBaade IA! Fitness: 7.826086956521739
# String: BoBQtarde, tuQIaXde IA! Fitness: 7.826086956521739
# String: Boa tarde, WubBaUGe IA! Fitness: 7.826086956521739
# String: Boa tardiKFturba de IAF Fitness: 7.826086956521739
# String: Boa darte, Uubma be IA! Fitness: 7.826086956521739
# String: Boa dard,n tuQIa de IA! Fitness: 7.826086956521739
# String: Bo, tardeG turcv dr IA! Fitness: 7.826086956521739
# String: BoaQtarde, ZuQIaXde IA! Fitness: 7.826086956521739
# String: Boa tardN,,tuQIa du IA! Fitness: 7.826086956521739
# String: BoaRtarde, bub!a Pe IA! Fitness: 7.826086956521739
# String: Boa tardU, tuQIaXdh IA! Fitness: 7.826086956521739
# String: BvaotHrde, tutBa de IA! Fitness: 7.826086956521739
# String: BoP taPde, UubBy de IA! Fitness: 7.391304347826087
# String: Boaotarde,ututBaoTe IA! Fitness: 7.391304347826087
# String: Bop Sardee Nurca dC IA! Fitness: 7.391304347826087
# String: Boa tardem UugBaDde IG! Fitness: 7.391304347826087
# String: Boa darden turlasYeJIA! Fitness: 7.391304347826087
# String: Boa Carde,CUubmayde WA! Fitness: 7.391304347826087
# String: Poa tardee Ndrca de oA! Fitness: 7.391304347826087
# String: Bos Cardee Nurca deTIA! Fitness: 7.391304347826087
# String: BoaMtaNdN, tuQIO de Ib! Fitness: 6.956521739130435
# String: Bza tarde, UubBaodT IAe Fitness: 6.956521739130435
# String: Boa fqrdee NurlT da IA! Fitness: 6.956521739130435
# String: BaaotaXde, tutBaode Iq! Fitness: 6.956521739130435
# String: Boy tardeW DuQpaXdB IA! Fitness: 6.956521739130435
# String: BPB da!den turla de Il! Fitness: 6.956521739130435
# String: Boa CRjdez  urNa du IA! Fitness: 6.956521739130435
# String: YgU tarde, NuxZaode IA! Fitness: 6.956521739130435
# String: BoaoParne,wtutBaode IAg Fitness: 6.521739130434782
# String: BoaUAardQ,NtHbma Ke pA! Fitness: 6.521739130434782
# String: Boaotarde, nztdaode .u! Fitness: 6.521739130434782
# String: BoQQtkrGe,mYulBa de IA! Fitness: 6.521739130434782
# String: j!H tardo, tWCIaXde IAe Fitness: 6.086956521739131
# Geração: 101
# String: Boa tarde, Ujbma de IA! Fitness: 8.695652173913043
# String: Boa tarden turla de IAX Fitness: 8.695652173913043
# String: Boa tarpen turla de IA! Fitness: 8.695652173913043
# String: Boa tarde, YulBa de IA! Fitness: 8.695652173913043
# String: Boa tarde, Uubma de IAS Fitness: 8.695652173913043
# String: Boaotarde, tutmaNde IA! Fitness: 8.695652173913043
# String: Boaotarde, tutma de IAS Fitness: 8.695652173913043
# String: Boa tardef turla dedIc! Fitness: 8.26086956521739
# String: Boaotarde, UubmM de IA! Fitness: 8.26086956521739
# String: Boa tarde, twtDaode IA! Fitness: 8.26086956521739
# String: Boa tarden tmrBa dp IA! Fitness: 8.26086956521739
# String: Bo, tarden turla de IAK Fitness: 8.26086956521739
# String: Bo,otarde,xtutma de IA! Fitness: 8.26086956521739
# String: Boa Warde, Yurc! de IA! Fitness: 8.26086956521739
# String: Boa tarde, Uubma decIAm Fitness: 8.26086956521739
# String: roa tDrden turla dM IA! Fitness: 7.826086956521739
# String: woa tarde, UuWmamde IAS Fitness: 7.826086956521739
# String: Boa tarde, YulBm dv IA! Fitness: 7.826086956521739
# String: B!a aarde, Yulqa de IA! Fitness: 7.826086956521739
# String: Boa darden turla de IiY Fitness: 7.826086956521739
# String: BoaQtarde, tuQIaXde hA! Fitness: 7.826086956521739
# String: Bo, tardeeCturc! de IA! Fitness: 7.826086956521739
# String: Boa Lardee turc! dX IA! Fitness: 7.826086956521739
# String: Boa tarde, YulBa de NAK Fitness: 7.826086956521739
# String: Boa tardxn turlTyde IA! Fitness: 7.826086956521739
# String: BoK Parde, tumBaode IA! Fitness: 7.826086956521739
# String: BoaQtarde, tuQIAXde IA! Fitness: 7.826086956521739
# String: BoaotardB, Uubma de GA! Fitness: 7.826086956521739
# String: Boa gardee turI! de nA! Fitness: 7.826086956521739
# String: BoaQtarde, xuQIaXde IA! Fitness: 7.826086956521739
# String: Boa barde, tutBaodl IA! Fitness: 7.826086956521739
# String: Boattarde, tutBaodl IA! Fitness: 7.826086956521739
# String: Boa thrdef tyrla de Ic! Fitness: 7.826086956521739
# String: BoagtardWe turc! de IA! Fitness: 7.826086956521739
# String: BIa taydef turla dZ IAC Fitness: 7.391304347826087
# String: Boe tarde, Yulqa .S IA! Fitness: 7.391304347826087
# String: Boa tardoA YulqA de IA! Fitness: 7.391304347826087
# String: BTa tarde,NYulBa deHIA! Fitness: 7.391304347826087
# String: Bofntardee tury! de AA! Fitness: 7.391304347826087
# String: Boa tardf, Iu,qa deJIAC Fitness: 7.391304347826087
# String: Boa uarde,WtuQIaXdT IA! Fitness: 7.391304347826087
# String: BoaotarSe, Uabma de IAS Fitness: 7.391304347826087
# String: Bo,Atarden turlavde yA! Fitness: 7.391304347826087
# String: Boa tarde, Uu,BamHeBIA! Fitness: 7.391304347826087
# String: Boa tarsefyturla de IYa Fitness: 7.391304347826087
# String: Baahtatde, Uubma de IAS Fitness: 7.391304347826087
# String: BWa tarkR, tuEBa Ge IA! Fitness: 7.391304347826087
# String: B aotarde,RUubya de IA! Fitness: 7.391304347826087
# String: doaotardR, qutmv de IAY Fitness: 6.956521739130435
# String: BoN eaWde, Uu,ha devIA! Fitness: 6.956521739130435
# String: Uoa tard!, tudBaoduHIA! Fitness: 6.956521739130435
# String: Boa tXrde, Y,lBN de IAa Fitness: 6.956521739130435
# String: BoaQPabde, tutBaode IAJ Fitness: 6.956521739130435
# String: BoaM.ardkN tKtba de IA! Fitness: 6.956521739130435
# String: Boo Yarde,hUukBa di IA! Fitness: 6.956521739130435
# String: Boaotarde,nUubma Oe.Icv Fitness: 6.521739130434782
# String: Bo, tardee tulqa h. Fz! Fitness: 6.521739130434782
# String: BWE tardQ, Uu,BaodQ IA! Fitness: 6.521739130434782
# String: Boa cardeN Yulli dX EQ! Fitness: 6.086956521739131
# String: BoaotaudeN lutBaodn XA! Fitness: 6.086956521739131
# Geração: 102
# String: Boa tardef turPa de IA! Fitness: 9.130434782608695
# String: Boaotarde, tubma de IA! Fitness: 9.130434782608695
# String: Boaotarde, tutma dN IA! Fitness: 8.695652173913043
# String: BoaoRarde, tutma de IA! Fitness: 8.695652173913043
# String: BoR tarde, Ujbma de IA! Fitness: 8.26086956521739
# String: Boa tardef turla dedIc! Fitness: 8.26086956521739
# String: Boaotarde, UubmM de IA! Fitness: 8.26086956521739
# String: Boa tarden tmrBa dp IA! Fitness: 8.26086956521739
# String: Boa tarde, twrla dedIc! Fitness: 8.26086956521739
# String: Boa taGpen turla de IA! Fitness: 8.26086956521739
# String: Boa tarpen tSrla de IA! Fitness: 8.26086956521739
# String: Boa tardeu tutmaNZe IA! Fitness: 8.26086956521739
# String: Boa tarde, YurBa dp IF! Fitness: 8.26086956521739
# String: Boa taade, YulBa de IA! Fitness: 8.26086956521739
# String: Boaotarde, tutmaNde IAh Fitness: 8.26086956521739
# String: Boa tarde, YulBa dl IA! Fitness: 8.26086956521739
# String: Boa tardenwturga de IAX Fitness: 8.26086956521739
# String: Boa tarde, YulBa de IAS Fitness: 8.26086956521739
# String: Boa tarde,,UubmP de IAM Fitness: 7.826086956521739
# String: Boaotarde, tQtma deyIAS Fitness: 7.826086956521739
# String: Bx, tarden turla de IAK Fitness: 7.826086956521739
# String: Boa tarzen tmrBa dp IA! Fitness: 7.826086956521739
# String: Boaotarde, UubmM re IA! Fitness: 7.826086956521739
# String: Bza taEde, tutma dv IAS Fitness: 7.826086956521739
# String: Boa tarde, YulBaDde Ic! Fitness: 7.826086956521739
# String: Box tardef turlavdedIA! Fitness: 7.826086956521739
# String: Boaotzrde, YulBa de IA! Fitness: 7.826086956521739
# String: Boa xarde, YulBa Fe IA! Fitness: 7.826086956521739
# String: BFN tardef tu Ba de IA! Fitness: 7.826086956521739
# String: Boa!tarde, UTbmM de IA! Fitness: 7.826086956521739
# String: Boa tarden tmrBY dp IA! Fitness: 7.826086956521739
# String: Boawtarde, UuqmM de II! Fitness: 7.826086956521739
# String: Boa tarFe, twtDaode IA! Fitness: 7.826086956521739
# String: Boa zaVden turla de SAX Fitness: 7.391304347826087
# String: Loa tarde,ZYulBa deKIA! Fitness: 7.391304347826087
# String: Bo,otardee tutmaNdepIA! Fitness: 7.391304347826087
# String: Boa tardIf tutDaode IAb Fitness: 7.391304347826087
# String: Bo, taxden turla be IAK Fitness: 7.391304347826087
# String: Uoaotardef turla dedIc! Fitness: 7.391304347826087
# String: Boa tar.e, Ujbma dp IAS Fitness: 7.391304347826087
# String: Boa ttrde, Uutma dt sAS Fitness: 7.391304347826087
# String: Boa sarde, twtDaode IAF Fitness: 7.391304347826087
# String: Boa turde, Uubma Ve zAS Fitness: 7.391304347826087
# String: Boaotarde, twtmaode dX! Fitness: 7.391304347826087
# String: BoaotardW, tudmjNdehIA! Fitness: 7.391304347826087
# String: Bxaotarde, tutmaBdeEIAS Fitness: 7.391304347826087
# String: BoaotaGde, UubmM De IA! Fitness: 7.391304347826087
# String: BoB tarkR, Uubma de IAS Fitness: 7.391304347826087
# String: Boa tarbt, twtDaodepIA! Fitness: 6.956521739130435
# String: Boaotnrdef tusla deDIc! Fitness: 6.956521739130435
# String: xoa tarde,LUfbmM deiIA! Fitness: 6.956521739130435
# String: BoaotMrdj,Vtubma dQ IA. Fitness: 6.956521739130435
# String: Bza tarde. Yulla deDIc! Fitness: 6.956521739130435
# String: Boa garde, Uubma Ce VSS Fitness: 6.956521739130435
# String: B!F XarZen tJrla deoIA! Fitness: 6.521739130434782
# String: BoaGtarpVn turlC deJIc! Fitness: 6.521739130434782
# String: BoC tarMe, UjtmaNdq IP! Fitness: 6.521739130434782
# String: BoYftarden tcIlaUde IMK Fitness: 6.086956521739131
# String: Boa tardAn tmlBavdeCno! Fitness: 6.086956521739131
# String: aoGAtardifiturlG dedIc! Fitness: 5.6521739130434785
# Geração: 103
# String: Boaotarde, tubma dm IA! Fitness: 8.695652173913043
# String: Boaotarde, tutma dj IA! Fitness: 8.695652173913043
# String: Boa tarde, twrPh de IA! Fitness: 8.695652173913043
# String: Boaotarde, tutma dN IA! Fitness: 8.695652173913043
# String: Boa tarde, UubmM de IA! Fitness: 8.695652173913043
# String: BoaHtarde, tutma dU IA! Fitness: 8.695652173913043
# String: Boa tarden tSrla de IA! Fitness: 8.695652173913043
# String: Bom tarde, twrla dedIA! Fitness: 8.26086956521739
# String: Boa tardef URbma de IA! Fitness: 8.26086956521739
# String: Boa tardef turla dedIc! Fitness: 8.26086956521739
# String: Boa tarqef turlA de IA! Fitness: 8.26086956521739
# String: Boa tafde, tutma .N IA! Fitness: 8.26086956521739
# String: Voa tardef turlayde IA! Fitness: 8.26086956521739
# String: Boaotarde, tutma dN SA! Fitness: 8.26086956521739
# String: Boa tarpen tSrla de IA! Fitness: 8.26086956521739
# String: BoaoRaxde, tutma du IA! Fitness: 7.826086956521739
# String: Boa tKrdeJ tmrBa dY IA! Fitness: 7.826086956521739
# String: Boa tardef putmaNZe IA! Fitness: 7.826086956521739
# String: BoaotardD, Uu.mM de IA! Fitness: 7.826086956521739
# String: Boj taGpen turla de IA! Fitness: 7.826086956521739
# String: Bo! tardeu tutmaNZe IA! Fitness: 7.826086956521739
# String: Boa tardef tBrPa dedIc! Fitness: 7.826086956521739
# String: BoR tarde, Ujbma dw IA! Fitness: 7.826086956521739
# String: BoaotXrde,Ktubma qe IA! Fitness: 7.826086956521739
# String: Boa tardef turla nedqA! Fitness: 7.826086956521739
# String: Boa tardeu tutmaNZe Ic! Fitness: 7.826086956521739
# String: Boa turpen tSrEa de IA! Fitness: 7.826086956521739
# String: BoaoRarde, tutcazde IA! Fitness: 7.826086956521739
# String: Boa tardsn tMrBa dp IA! Fitness: 7.826086956521739
# String: BoU tnrde, tupma eN IA! Fitness: 7.826086956521739
# String: BoB tarde, tutsaNZe IA! Fitness: 7.826086956521739
# String: Boa vardef turPafNe wA! Fitness: 7.391304347826087
# String: Boa tardef tutlaydedIc! Fitness: 7.391304347826087
# String: Boa taGpen Zurla de HA! Fitness: 7.391304347826087
# String: BoxXtarde, rurla dedIc! Fitness: 7.391304347826087
# String: Boa tarden tmrBa dp I!e Fitness: 7.391304347826087
# String: BoC tardefLturla dedIc! Fitness: 7.391304347826087
# String: Boa tarpenhtSrlu de IA! Fitness: 7.391304347826087
# String: BoaotaGpen turla de TA! Fitness: 7.391304347826087
# String: Boa taGpenQturla be IA! Fitness: 7.391304347826087
# String: BoZ tarde, UjbmG ce IA! Fitness: 7.391304347826087
# String: Boaotarde, Adrla dedIc! Fitness: 7.391304347826087
# String: Boa tardeu twrlN dedIc! Fitness: 7.391304347826087
# String: NPR tarde, Ujbma de Ib! Fitness: 6.956521739130435
# String: Boaoearde,!UubqM de IA! Fitness: 6.956521739130435
# String: Boy ta!den tmrBa dp IO! Fitness: 6.956521739130435
# String: Boa tarNen tmrBaxdp Ig! Fitness: 6.956521739130435
# String: BoT tardKf t rla dedIc! Fitness: 6.956521739130435
# String: Bba tNrdeu tutma d. Iut Fitness: 6.956521739130435
# String: Goa tarpe, tmeBq dp IA! Fitness: 6.956521739130435
# String: Bos taxpen tSGld de IA! Fitness: 6.521739130434782
# String: Boa hardeuItxtmaNZe IK! Fitness: 6.521739130434782
# String: Boa tKGxen tVrla dedIc! Fitness: 6.521739130434782
# String: Boaotardh, UubeM de IaR Fitness: 6.521739130434782
# String: ioe HaGpen iurla de IA! Fitness: 6.521739130434782
# String: BoR taWde, JjbmaNZe IAB Fitness: 6.521739130434782
# String: moaotPrde, twrla!dedIc! Fitness: 6.521739130434782
# String: BoKkRardeOUtmrBa dp IA! Fitness: 6.521739130434782
# String: toa ylrHe, twrla dadmc! Fitness: 5.6521739130434785
# String: Boa .afdyudtutmaNZy PA! Fitness: 5.6521739130434785
# Geração: 104
# String: Boa tardef turla dedIA! Fitness: 8.695652173913043
# String: Boaotarde, tubma dm IA! Fitness: 8.695652173913043
# String: Boa Varde, twrPh de IA! Fitness: 8.26086956521739
# String: Boaotarde, tutaa dN IA! Fitness: 8.26086956521739
# String: BSaotarde, tutma dj IA! Fitness: 8.26086956521739
# String: Bombtarde, twrma dU IA! Fitness: 8.26086956521739
# String: Boa.tarde, tltma dQ IA! Fitness: 8.26086956521739
# String: Boa tardeQ tubma dm zA! Fitness: 8.26086956521739
# String: Boa tarNen tSrla de IA! Fitness: 8.26086956521739
# String: BoaTtardI, tubma dA IA! Fitness: 8.26086956521739
# String: BoaotaYde, tutma dj IA! Fitness: 8.26086956521739
# String: Boa tardef twrla dedIA! Fitness: 8.26086956521739
# String: Boa tardek tSrla de IW! Fitness: 8.26086956521739
# String: Boa tarde, twrPh dz IA! Fitness: 8.26086956521739
# String: Boaotarde, tuzna dU IA! Fitness: 8.26086956521739
# String: BoNotarde,xtubma dy IA! Fitness: 7.826086956521739
# String: Boa tarfef URbma de IA! Fitness: 7.826086956521739
# String: Boa taDde, twrPh dC IA! Fitness: 7.826086956521739
# String: Boaotarne, tubma dm Is! Fitness: 7.826086956521739
# String: BoaHtarde, tutla dedwA! Fitness: 7.826086956521739
# String: Boaotardef UD,ma de IA! Fitness: 7.826086956521739
# String: Boa tardeV twrla FedIA! Fitness: 7.826086956521739
# String: Bom tafde, tutma .N IA! Fitness: 7.826086956521739
# String: Bva tarden tuIma .N IA! Fitness: 7.826086956521739
# String: Boa tardP,lUubmM de IA! Fitness: 7.826086956521739
# String: moaotaede, tutma dj IA! Fitness: 7.826086956521739
# String: Boa Fardef URbma de IA! Fitness: 7.826086956521739
# String: Boa tardeDZtSkxa de IA! Fitness: 7.826086956521739
# String: Boa tarqef tdrlA de IA! Fitness: 7.826086956521739
# String: Boa tarqef turpA dm IA! Fitness: 7.826086956521739
# String: BoaHvarde, tutmK dj IA! Fitness: 7.826086956521739
# String: BoaMtprde, tut.a dN IA! Fitness: 7.826086956521739
# String: BoaHtadje, tutma dj IA! Fitness: 7.826086956521739
# String: BoKHtardE, tutma pU IA! Fitness: 7.391304347826087
# String: Boa parsen tSrla de Ib! Fitness: 7.391304347826087
# String: Bom Carde, twrla dedIf! Fitness: 7.391304347826087
# String: goa tarqef turlA de Ir! Fitness: 7.391304347826087
# String: BjaotarXe, tutYa dN IA! Fitness: 7.391304347826087
# String: BoaotardeAutSrlX de IA! Fitness: 7.391304347826087
# String: Boa Eacde. tSrla ye IA! Fitness: 7.391304347826087
# String: Loa tardef URbmY de IA! Fitness: 7.391304347826087
# String: BoaotaYde,btutma um IA! Fitness: 7.391304347826087
# String: Doa tardef Uqbmande IA! Fitness: 7.391304347826087
# String: Bom tardef turla dldIc! Fitness: 7.391304347826087
# String: Boaotarde, xubmahdeIIAz Fitness: 7.391304347826087
# String: BNa tafde, tutmaq.N IA! Fitness: 7.391304347826087
# String: eoaotardd, Rutma dU IA! Fitness: 7.391304347826087
# String: Boa tardef tuPlaAdedIc! Fitness: 7.391304347826087
# String: Boaotarre, Qukma dm Ic! Fitness: 7.391304347826087
# String: BoaotNrde,Ltutma dj lA! Fitness: 7.391304347826087
# String: ooAotavdew tutma dj IA! Fitness: 6.956521739130435
# String: BoO tardef tbrla deaIcg Fitness: 6.956521739130435
# String: Bwa tafde,Qtutm  .c IA! Fitness: 6.956521739130435
# String: goJ tardA, UubmM Me IA! Fitness: 6.956521739130435
# String: Boa tDfde, tutmX .NQIA! Fitness: 6.956521739130435
# String: Moa tafde,JButma .N IA! Fitness: 6.956521739130435
# String: foa tardGfQturla dedIc! Fitness: 6.956521739130435
# String: Ooa oaCde, UubrM dx IA! Fitness: 6.521739130434782
# String: Bom tardehcZdtla dedIAO Fitness: 6.086956521739131
# String: Bo,ota Se,htubmaqdm nx! Fitness: 5.6521739130434785
# Geração: 105
# String: Boa tardef turla dg IA! Fitness: 8.695652173913043
# String: BoaQtarde, twrma dU IA! Fitness: 8.695652173913043
# String: Boa Varde, twrla de IA! Fitness: 8.695652173913043
# String: Boa tardef turla dedIA! Fitness: 8.695652173913043
# String: Boaotarde, tubmF dm IA! Fitness: 8.26086956521739
# String: BoaTtardI, tubma dA IA! Fitness: 8.26086956521739
# String: BoaotaYde, tutma dj IA! Fitness: 8.26086956521739
# String: Boaotarde, tubma Ym IA! Fitness: 8.26086956521739
# String: BoaFtarde, tlBma dQ IA! Fitness: 8.26086956521739
# String: Boa tarde, tubGB dm IA! Fitness: 8.26086956521739
# String: Boa tardef tubla dedqA! Fitness: 7.826086956521739
# String: BoaUVarde, twrPh de IA! Fitness: 7.826086956521739
# String: Boa tarNen tSrea de IAV Fitness: 7.826086956521739
# String: Boa tardMs twrla dedIA! Fitness: 7.826086956521739
# String: Boa tardef Iurla dJdIA! Fitness: 7.826086956521739
# String: Bombtardr, tArma dU IA! Fitness: 7.826086956521739
# String: BoIbtarde, tubma nm IA! Fitness: 7.826086956521739
# String: BoaotaYde, tuqma dj Ie! Fitness: 7.826086956521739
# String: BoavtarNen tSrla de IA! Fitness: 7.826086956521739
# String: Boaotarae, tubmV dm IA! Fitness: 7.826086956521739
# String: BZa jarde, twrPh de IA! Fitness: 7.826086956521739
# String: Boa Vaode, twrPQ de IA! Fitness: 7.826086956521739
# String: Joa Varde, tutaa dN IA! Fitness: 7.826086956521739
# String: BoaCtarde, tltma dQ IB! Fitness: 7.826086956521739
# String: Boa tarNen tSrla desIA! Fitness: 7.826086956521739
# String: Boaotarde, twKma dU Ih! Fitness: 7.826086956521739
# String: Bwmbtarde, tubma dm IA! Fitness: 7.826086956521739
# String: Boa.tarde, .utma ,j IA! Fitness: 7.826086956521739
# String: Boaotarze, tubma dm zA! Fitness: 7.826086956521739
# String: Boaotarde, tutaa dT,It! Fitness: 7.391304347826087
# String: BSaogarde, tutma dj FA! Fitness: 7.391304347826087
# String: Bombtarde, twrma dU IaM Fitness: 7.391304347826087
# String: Soa.tarde, tYtma dQ Ip! Fitness: 7.391304347826087
# String: yoa tardeQ Zubma dm zA! Fitness: 7.391304347826087
# String: Boa tarHen qSrla dedIA! Fitness: 7.391304347826087
# String: Boxooarde, tutaa dN IA! Fitness: 7.391304347826087
# String: Soa.Varde, twrPh de IA! Fitness: 7.391304347826087
# String: BoaTtardI, wubma dABIA! Fitness: 7.391304347826087
# String: Boa YarNen tSrla de BA! Fitness: 7.391304347826087
# String: Boa tWrdeQ tubmaWdm zA! Fitness: 7.391304347826087
# String: BoaotarVe, tubmT dmXIA! Fitness: 7.391304347826087
# String: Boaoaarde, twrPh de kA! Fitness: 7.391304347826087
# String: Boa tarRe, ,utmaBdj Ij! Fitness: 7.391304347826087
# String: Boa tarNen tSrlt de IAD Fitness: 7.391304347826087
# String: BoaoNarde, tutaa dN JA! Fitness: 7.391304347826087
# String: Boa tardeQ!Cubma dm zA! Fitness: 7.391304347826087
# String: BSao!arje, tutma dj IA! Fitness: 7.391304347826087
# String: Bon.tarde, tltmb dQ IA! Fitness: 7.391304347826087
# String: BoaotlYde, tltma dQ IA! Fitness: 7.391304347826087
# String: Bol VIrde, twrFh de IA! Fitness: 7.391304347826087
# String: BoZotaYde, nutma,dj IA! Fitness: 6.956521739130435
# String: BoantarNenntSrPh de IA! Fitness: 6.956521739130435
# String: B.aotvrde, tutaI dN IA! Fitness: 6.956521739130435
# String: BCaotardeiStSrlaYde IA! Fitness: 6.956521739130435
# String: BoaYtardeQftutaa dN IAt Fitness: 6.956521739130435
# String: Boa VardeXftwrPh deCIA! Fitness: 6.956521739130435
# String: BoaitnrNenstSrla ie IA! Fitness: 6.521739130434782
# String: Qoa CardeQ tubmeydm fAj Fitness: 6.086956521739131
# String: tiIotardef twrla deHIAE Fitness: 6.086956521739131
# String: BoNfbarNen tSrlaade cH! Fitness: 5.6521739130434785
# Geração: 106
# String: Boa tardef turla dg IA! Fitness: 8.695652173913043
# String: Boa Varde, twrla de IA! Fitness: 8.695652173913043
# String: Boaotarde, twrma dU IA! Fitness: 8.695652173913043
# String: Boa tardef tuBma dR IA! Fitness: 8.695652173913043
# String: Bo. tarde, twrla de IA! Fitness: 8.695652173913043
# String: Boa tardef turla dedIA! Fitness: 8.695652173913043
# String: Boa tardef turla du IA! Fitness: 8.695652173913043
# String: Boa Earde, twrla de IA! Fitness: 8.695652173913043
# String: Boaotarde, tubma Ym IA! Fitness: 8.26086956521739
# String: Boa tardef turla dgMIA! Fitness: 8.26086956521739
# String: Boaotarde, tubma Ym IA! Fitness: 8.26086956521739
# String: BoaFtarde, tlBma dg IA! Fitness: 8.26086956521739
# String: Boa oarde, twrPh de IA! Fitness: 8.26086956521739
# String: Boa Rardef turla deIIA! Fitness: 8.26086956521739
# String: Boa tardI,Ytubma dA IA! Fitness: 8.26086956521739
# String: BoaTtardI, tubma dx IA! Fitness: 8.26086956521739
# String: Boaotarde, twrPh de IA! Fitness: 8.26086956521739
# String: BoaQtarSe, twrma pU IA! Fitness: 7.826086956521739
# String: Boaotarde, tcbmF dm IA! Fitness: 7.826086956521739
# String: SoaotaYde, tutma dj IA! Fitness: 7.826086956521739
# String: BoaFtarde, tlBmagdQ IA! Fitness: 7.826086956521739
# String: Boa tardef tuBNa dg IAe Fitness: 7.826086956521739
# String: Boa Varde, twrla we IAd Fitness: 7.826086956521739
# String: Boa tarde, tubGBAdm IA! Fitness: 7.826086956521739
# String: Boa tardef thrla dQ IAm Fitness: 7.826086956521739
# String: Boa tirde, tubGB dm IA! Fitness: 7.826086956521739
# String: Boa tarde, tCbGB dm IA! Fitness: 7.826086956521739
# String: BPa tardef turlamdg IA! Fitness: 7.826086956521739
# String: Boa tarte, tlBma hQ IA! Fitness: 7.826086956521739
# String: BJaotarde, tubmF dm IA! Fitness: 7.826086956521739
# String: BoaUVarde, twrPh de IA! Fitness: 7.826086956521739
# String: BoaotaYde, tukmaRdm IA! Fitness: 7.826086956521739
# String: BoaTtaMdI, tubea dX IA! Fitness: 7.391304347826087
# String: BoK taqde, tubGB dm IA! Fitness: 7.391304347826087
# ...
# String: Boaqtnrmeo turmD de IA! Fitness: 7.826086956521739
# String: BoaztaYse, purmE de IA! Fitness: 7.826086956521739
# String: Boa taRde, turiGZce IA! Fitness: 7.826086956521739
# String: BPa ,arde, duKma de IK! Fitness: 7.826086956521739
# String: BoaItarde,xtuRma dI Ie! Fitness: 7.826086956521739
# String: Boa taYse, turmE de QK! Fitness: 7.826086956521739
# String: Boa tnrAe, turmD deYIn! Fitness: 7.826086956521739
# String: Boa taYse, tyrmE Ue IA! Fitness: 7.826086956521739
# String: Boa tar.e,,WXrma de I ! Fitness: 7.826086956521739
# String: Boa taRde,tturmG c. IA! Fitness: 7.826086956521739
# String: qoa tar.e,kcurmD de IA! Fitness: 7.826086956521739
# String: BoaIpakde, tuRmD de IA! Fitness: 7.826086956521739
# String: Boa taJde,,tGrma Ue Iex Fitness: 7.391304347826087
# String: BoasOYrZe, turmt de IE! Fitness: 7.391304347826087
# String: Boa tarde,otcrmt deGXE! Fitness: 7.391304347826087
# String: MoaItarde,bVuRma de Ie! Fitness: 7.391304347826087
# String: BPa Karhe,TtuRma de Ie! Fitness: 7.391304347826087
# String: Boa tar.eU,tXrma dm TA! Fitness: 7.391304347826087
# String: Bou XPWse, turmE de IA! Fitness: 7.391304347826087
# String: MomILarde, tuRma de Ie! Fitness: 7.391304347826087
# String: BPaIKaxde,Lturma Te IA! Fitness: 7.391304347826087
# String: JoM WaRde, turmG ce IA! Fitness: 7.391304347826087
# String: BoaBtaRdec tQrbG ce IA! Fitness: 6.956521739130435
# String: Boa tgrde,qdulta de IKd Fitness: 6.956521739130435
# String: poaEtaJde,ftGrma Ee IX! Fitness: 6.956521739130435
# String: koU taRde, tTrmGtce IA! Fitness: 6.956521739130435
# String: IoR taJde,ftermwode IA! Fitness: 6.956521739130435
# String: BWa Oarde, buamt de LE! Fitness: 6.956521739130435
# String: CoD tArAe, turmrhde Ie! Fitness: 6.956521739130435
# String: Boa tnMseC vurdaxde IT! Fitness: 6.521739130434782
# String: Boa tnrAT,FtXrma deTQAB Fitness: 6.521739130434782
# Geração: 171
# String: Boa tarse, turma de ,A! Fitness: 9.130434782608695
# String: BoaItQrde, turma de IA! Fitness: 9.130434782608695
# String: Boa tarde, turFa deuIA! Fitness: 9.130434782608695
# String: Boa Oarde, tkrma de IA! Fitness: 9.130434782608695
# String: BoaMtarde, tuRma de IA! Fitness: 9.130434782608695
# String: Boantarde, durmd de IA! Fitness: 8.695652173913043
# String: BoaItarde, tuRma de Ie! Fitness: 8.695652173913043
# String: Boa tarde, duxmd de IA! Fitness: 8.695652173913043
# String: Boa Oarde, turma do Ix! Fitness: 8.695652173913043
# String: eoa tBrse, turma de IA! Fitness: 8.695652173913043
# String: Boa uarse,Jturma de IA! Fitness: 8.695652173913043
# String: BoC tard!, durma de IA! Fitness: 8.695652173913043
# String: BoaZtarde, durma de IK! Fitness: 8.695652173913043
# String: BoaItQr e, turma de IA! Fitness: 8.695652173913043
# String: Boa tarze,cturma de Iu! Fitness: 8.695652173913043
# String: dNa tarde, durma de IA! Fitness: 8.695652173913043
# String: BoaItarde, turma do IT! Fitness: 8.695652173913043
# String: Loa tdrse, turma de IA! Fitness: 8.695652173913043
# String: Bya rarde, turFa de IA! Fitness: 8.695652173913043
# String: BoaItarde, tuyma de Ie! Fitness: 8.695652173913043
# String: Boautarde, durma de IZk Fitness: 8.26086956521739
# String: Boa taJdeDftGrma de IA! Fitness: 8.26086956521739
# String: ByS tQrde, tuPma de IA! Fitness: 8.26086956521739
# String: BoautardQ, durma de RA! Fitness: 8.26086956521739
# String: BoaQtarde, durmaAde fA! Fitness: 8.26086956521739
# String: BoaItardZ, turma do IO! Fitness: 8.26086956521739
# String: Boa Oarde, tuRma de Iay Fitness: 8.26086956521739
# String: BoaKtnrse, turFa de IA! Fitness: 8.26086956521739
# String: Roautarde, durma de Im! Fitness: 8.26086956521739
# String: BoaItardeY tuRma de Ie! Fitness: 8.26086956521739
# String: BoaItardX, tuRma se IA! Fitness: 8.26086956521739
# String: BoaItQrde, turmadde Ie! Fitness: 8.26086956521739
# String: BoaUOarde, turma do tO! Fitness: 7.826086956521739
# String: hoS tar.e,,tXrma de IA! Fitness: 7.826086956521739
# String: Boa terze,ctcrma do IA! Fitness: 7.826086956521739
# String: BoaIrarde,wtDrma de IAA Fitness: 7.826086956521739
# String: BoC tarde,PtuTma dH IAx Fitness: 7.826086956521739
# String: Zoa OardeY turma do IO! Fitness: 7.826086956521739
# String: BgaHtarde, Lurmd de IAt Fitness: 7.826086956521739
# String: Boa Oarde,MtuRma de Iep Fitness: 7.826086956521739
# String: BoaKtnrse, durmr de IA! Fitness: 7.826086956521739
# String: Boa tarze,ctcrma do IAY Fitness: 7.826086956521739
# String: YoaCtarde, duKma de IK! Fitness: 7.826086956521739
# String: BJa tarze,nyGrma de IA! Fitness: 7.826086956521739
# String: BoB tardZ, ducmd de IA! Fitness: 7.826086956521739
# String: BoBKtnrse,wturma de IA! Fitness: 7.826086956521739
# String: BoC tarde, dOrmF ze IK! Fitness: 7.391304347826087
# String: ByT rarde wturma je IA! Fitness: 7.391304347826087
# String: BoaKtnrse, tuAFaUde IA! Fitness: 7.391304347826087
# String: Boa tarEn, durmd deQcA! Fitness: 7.391304347826087
# String: Bo.utardc, duemd de IA! Fitness: 7.391304347826087
# String: Bya rardeTwtcrma do IA! Fitness: 7.391304347826087
# String: Vfa tar.e,ltXrma dK IA! Fitness: 7.391304347826087
# String: Boautarde, dNrmd ie IAr Fitness: 7.391304347826087
# String: Bya rarde,wturma de Deq Fitness: 7.391304347826087
# String: KoC OIrde, turma No IO! Fitness: 6.956521739130435
# String: BoaItQrze,fdCrma de IKk Fitness: 6.521739130434782
# String: Ioa sar.e,,eXrma da IAn Fitness: 6.521739130434782
# String: BoF tDJde,fucrma do Iy! Fitness: 6.521739130434782
# String: BoaKtnrse, turFf Ao IO! Fitness: 6.521739130434782
# Geração: 172
# String: Boa tarse, turma de bA! Fitness: 9.130434782608695
# String: BoaMtarde,Jturma de IA! Fitness: 9.130434782608695
# String: Boa tarde, turFa de HA! Fitness: 9.130434782608695
# String: Boa tarke, turma deuIA! Fitness: 9.130434782608695
# String: BoaItQrde, turma de IA! Fitness: 9.130434782608695
# String: BoaItQrde, turmacde IA! Fitness: 8.695652173913043
# String: BoaItarde, tuRma de Ie! Fitness: 8.695652173913043
# String: BoC Bard!, turma de IA! Fitness: 8.695652173913043
# String: BoaMtarde, tuRma de IAF Fitness: 8.695652173913043
# String: Boa tarde, turFa deuIAN Fitness: 8.695652173913043
# String: Boa tarde, duxmd de IA! Fitness: 8.695652173913043
# String: BoaMtarde, tuRm  de IA! Fitness: 8.695652173913043
# String: BoaMtardk, tuRma de IA! Fitness: 8.695652173913043
# String: BoaMtarde, tuRma de In! Fitness: 8.695652173913043
# String: BoaIEQrde, turma de IA! Fitness: 8.695652173913043
# String: Boa farse, turmY de IA! Fitness: 8.695652173913043
# String: Boa OarTe, turma do IA! Fitness: 8.695652173913043
# String: Boa tarde,QturFa dAuIA! Fitness: 8.26086956521739
# String: Boa tarde, duxmd de PA! Fitness: 8.26086956521739
# String: Boa uarse,Jzurma de IA! Fitness: 8.26086956521739
# String: BoC tard!, durma deWIA! Fitness: 8.26086956521739
# String: Boa tarse, tuRma deGIe! Fitness: 8.26086956521739
# String: BvK tarde, turFd de IA! Fitness: 8.26086956521739
# String: eoa tBrse, durma de IA! Fitness: 8.26086956521739
# String: Boa Iarde, duxmd de IA! Fitness: 8.26086956521739
# String: Boa Oarde, tfrma do IR! Fitness: 8.26086956521739
# String: eoa tBrsF, turma de IA! Fitness: 8.26086956521739
# String: eoa tBrse, turmaLde IA! Fitness: 8.26086956521739
# String: Coantarde, durmd de IA! Fitness: 8.26086956521739
# String: Boa uarse,Jturma de Ix! Fitness: 8.26086956521739
# String: eoa fBrse, turma de IA! Fitness: 8.26086956521739
# String: Boa OQWde, turma ne IA! Fitness: 8.26086956521739
# String: Koa Oarde, tkrmu devIA! Fitness: 7.826086956521739
# String: Boantardf, durmd de IG! Fitness: 7.826086956521739
# String: eoa .Brse, tCrma de IA! Fitness: 7.826086956521739
# String: BoaItardX, turmag,e ,A! Fitness: 7.826086956521739
# String: BoaJtardi, durma dePIM! Fitness: 7.826086956521739
# String: BoaLuarso, tuRma de IA! Fitness: 7.826086956521739
# String: B tntarde, ducma de IA! Fitness: 7.826086956521739
# String: BoaItQrde, gXrma ds IA! Fitness: 7.826086956521739
# String: BobItardP, tuRmo de IA! Fitness: 7.826086956521739
# String: BoaItardI, tusma Uu IA! Fitness: 7.826086956521739
# String: Boa OardS,btkrQa de IA! Fitness: 7.826086956521739
# String: BoaItardeY tuKma deiIe! Fitness: 7.826086956521739
# String: Bot tabde, duxmd de IA! Fitness: 7.826086956521739
# String: Boa Warde, duxmd de ,A! Fitness: 7.826086956521739
# String: BoCQtard!, durma de Ix! Fitness: 7.826086956521739
# String: BovMtarde, tuRmF le IAd Fitness: 7.391304347826087
# String: BoC tard!,,duLmd de IA! Fitness: 7.391304347826087
# String: BoaMtarke, tuRb Dde IA! Fitness: 7.391304347826087
# String: BoaMtaYde, UuRma de Be! Fitness: 7.391304347826087
# String: Xoa tarseB turma Ge ,Aw Fitness: 7.391304347826087
# String: BGaiuaJse,Jturma de IA! Fitness: 7.391304347826087
# String: BoaMta de, tJRma ds IeC Fitness: 6.956521739130435
# String: BoaIt rdeu turRa do Nx! Fitness: 6.956521739130435
# String: PoW OarUeEYturma do Ix! Fitness: 6.521739130434782
# String: BoC eard!,Mdurha re Ix! Fitness: 6.521739130434782
# String: BRCztard!, durm,AdekIA! Fitness: 6.521739130434782
# String: Boa OarUeg jlqmR do IA! Fitness: 6.521739130434782
# String: eMa tBrseu HsrmKMde IA! Fitness: 6.086956521739131
# Geração: 173
# String: Boa Barde, turma de IA! Fitness: 9.565217391304348
# String: Boa tarde, turFa de IA! Fitness: 9.565217391304348
# String: Boa tarde, turma de,bA! Fitness: 9.130434782608695
# String: Boa tarxe, turmatde IA! Fitness: 9.130434782608695
# String: Boa tarde, turFa de HA! Fitness: 9.130434782608695
# String: Boa tarke, turma le IA! Fitness: 9.130434782608695
# String: BoaItQrde, turma de IA! Fitness: 9.130434782608695
# String: Boa tardO, turda de mA! Fitness: 8.695652173913043
# String: BoaItarde, tuCma de Ie! Fitness: 8.695652173913043
# String: Boa tmrse, turma de bA! Fitness: 8.695652173913043
# String: BoastQEde, turma de IA! Fitness: 8.695652173913043
# String: Boa tarse, turma du NA! Fitness: 8.695652173913043
# String: Boa tarse, tNrma degbA! Fitness: 8.26086956521739
# String: BoaMtardE,Jturma me IA! Fitness: 8.26086956521739
# String: BoC tarde, turFa dg HA! Fitness: 8.26086956521739
# String: Poa tarde, cuxmd de IA! Fitness: 8.26086956521739
# String: BoaItarde, tuRma de IVF Fitness: 8.26086956521739
# String: BoaMtardr, tuRma de Ie! Fitness: 8.26086956521739
# String: Boa tarje, duxmacde IA! Fitness: 8.26086956521739
# String: BjaItarde,Jturma de IAf Fitness: 8.26086956521739
# String: BoaMtarde, euRma de Ie! Fitness: 8.26086956521739
# String: BoaMGYrde, tuRma de IA! Fitness: 8.26086956521739
# String: Boa taTde, turFa dq HA! Fitness: 8.26086956521739
# String: BoaItardB, turmo de IW! Fitness: 8.26086956521739
# String: B!C Bard!, turmaude IA! Fitness: 7.826086956521739
# String: BoaMSarde, tuimn de IAF Fitness: 7.826086956521739
# String: Boa tarde, turFa zeueAN Fitness: 7.826086956521739
# String: Boa taXde, duxmdXde IA! Fitness: 7.826086956521739
# String: BoaItardeU tuRma fe Ie! Fitness: 7.826086956521739
# String: BoaItQrQe, turmdMde IA! Fitness: 7.826086956521739
# String: Boa tardV, turFhbde HA! Fitness: 7.826086956521739
# String: foa tarde, duxmd de IAK Fitness: 7.826086956521739
# String: Boa tarLedZtvGma de IA! Fitness: 7.826086956521739
# String: BoC Bard!, tu.my de IA! Fitness: 7.826086956521739
# String: BkaMtavde, tuRma de Ie! Fitness: 7.826086956521739
# String: BoFMtarde,Jturma df !A! Fitness: 7.826086956521739
# String: Boa tarWe, tur,a de HRW Fitness: 7.826086956521739
# String: Boa tarke, turmenzeFkA! Fitness: 7.391304347826087
# String: BjaItIrde, uurma deJXA! Fitness: 7.391304347826087
# String: BKaItQrde, purmacde IAt Fitness: 7.391304347826087
# String: ZoaMtardp, tuLx  de IA! Fitness: 7.391304347826087
# String: BoaptarUe, turFW Ee HA! Fitness: 7.391304347826087
# String: BoaMtaede,ituRma Re IAF Fitness: 7.391304347826087
# String: BoaMtQrde, tuRm  oe IAi Fitness: 7.391304347826087
# String: Zoa tarde,qduxmd Be IA! Fitness: 7.391304347826087
# String: BoaItardD, turFK deuIAN Fitness: 7.391304347826087
# String: Boa taPde, tuRma weEHe! Fitness: 7.391304347826087
# String: KoaItarde, tuRdaXde IAF Fitness: 7.391304347826087
# String: Boa tarKe, turFa douzAN Fitness: 7.391304347826087
# String: BoiItQrde, turmaRdWuIA! Fitness: 7.391304347826087
# String: qob tarde, turFaideuIAq Fitness: 7.391304347826087
# String: BoC BarceB tuRma de Ie! Fitness: 7.391304347826087
# String: BoaMta!de, tiRmaPde TAF Fitness: 6.956521739130435
# String: BovMtarRe,StuRmn de HA! Fitness: 6.956521739130435
# String: BrCohard!, turma de bAi Fitness: 6.956521739130435
# String: JobMtarde,JtSrma XeuIA! Fitness: 6.956521739130435
# String: BoaMtardwU IuRma deEGA! Fitness: 6.956521739130435
# String: LoaIts,de,dtusma de IAF Fitness: 6.956521739130435
# String: Boa taZdeg turFa,deuRAN Fitness: 6.956521739130435
# String: BvaMtardeVJturdande I!F Fitness: 6.521739130434782
# Geração: 174
# String: Boa tarde, turma de IA! Fitness: 10.0
# String: Boa tarde, turFa de HA! Fitness: 9.130434782608695
# String: Boa tarde, tuDFa de IA! Fitness: 9.130434782608695
# String: Boa tarde, turda de mA! Fitness: 9.130434782608695
# String: Boa tjrde, turma deNIA! Fitness: 9.130434782608695
# String: Bta tarqe, turma de IA! Fitness: 9.130434782608695
# String: Boa tarke, turma de IAz Fitness: 9.130434782608695
# String: Boa terde, turma de,bA! Fitness: 8.695652173913043
# String: BoaItQrdev turma de IA! Fitness: 8.695652173913043
# String: Boaotarde, tuJFa de IA! Fitness: 8.695652173913043
# String: BoJ t,rde, turmatde IA! Fitness: 8.695652173913043
# String: Boa tarde, turda dS mA! Fitness: 8.695652173913043
# String: Boa tarse, turma du NA! Fitness: 8.695652173913043
# String: BoaQtQrde, turma de IAN Fitness: 8.695652173913043
# String: Boa BaPde, turmE de IA! Fitness: 8.695652173913043
# String: Boa Uarde, turda de mA! Fitness: 8.695652173913043
# String: Boa taLke, turma le IA! Fitness: 8.695652173913043
# String: Boa marse, turmatde IA! Fitness: 8.695652173913043
# String: Boa oXrdv, turma Re IA! Fitness: 8.26086956521739
# String: BoV tardR, gur.a de IA! Fitness: 8.26086956521739
# String: Box tarke, gurma le IA! Fitness: 8.26086956521739
# String: Boa tnrse, ,urma de bA! Fitness: 8.26086956521739
# String: BoastQEdB, turma de IA! Fitness: 8.26086956521739
# String: Boa tarse, turmO du NA! Fitness: 8.26086956521739
# String: B a tarde, turFa de IqG Fitness: 8.26086956521739
# String: Boa tarse, twrma du bA! Fitness: 8.26086956521739
# String: Boa tardO, turFa de HAU Fitness: 8.26086956521739
# String: Boa tarxe, fZrmatde IA! Fitness: 8.26086956521739
# String: Boa tarXe, turFa de,bA! Fitness: 8.26086956521739
# String: Boa tarkes turma le HA! Fitness: 8.26086956521739
# String: BoQ ta.de,kturFa de IA! Fitness: 8.26086956521739
# String: Bos tJrxe, turmatde IA! Fitness: 8.26086956521739
# String: Boa taCdO, turma de,bA! Fitness: 8.26086956521739
# String: BJz tardW, turFa de IA! Fitness: 8.26086956521739
# String: Boa tarde, turFc ne Iy! Fitness: 8.26086956521739
# String: Boa tardO, tukAa de mA! Fitness: 8.26086956521739
# String: Boa BaAde, turma le Id! Fitness: 8.26086956521739
# String: BoaHtTrde, tunma dZ IA! Fitness: 8.26086956521739
# String: Bon tarxe, turma du NA! Fitness: 8.26086956521739
# String: Boa Rayxe, tuKmatde IA! Fitness: 7.826086956521739
# String: Bqa tbrde, turmH de,bA! Fitness: 7.826086956521739
# String: Boa tarTm, turm, le IAb Fitness: 7.826086956521739
# String: zja tarde, ,urma we IAF Fitness: 7.826086956521739
# String: BoaItarse, turma gu NA! Fitness: 7.826086956521739
# String: BMaItQrYe, turmatde IA! Fitness: 7.826086956521739
# String: BoaHOardO, turda de HA! Fitness: 7.826086956521739
# String: Bon BardR, turma de mAq Fitness: 7.826086956521739
# String: Boy tardO, wurda ge IA! Fitness: 7.826086956521739
# String: Bo!MtQgde, turmacde IA! Fitness: 7.826086956521739
# String: Boa tmrse, tuAma denbA! Fitness: 7.826086956521739
# String: BoaJtarxe, tuRmatdeKIk! Fitness: 7.391304347826087
# String: BoaItarde,FtVCma!de Ie! Fitness: 7.391304347826087
# String: Boa tArse, tuHwa dx bA! Fitness: 7.391304347826087
# String: Boz tabxM, turFa de HA! Fitness: 7.391304347826087
# String: BoaItaXde,dtACma de Ie! Fitness: 7.391304347826087
# String: VeastQEde, turma ne NA! Fitness: 6.956521739130435
# String: foautQrdef turmW de,OA! Fitness: 6.956521739130435
# String: BZa tardeO.turma he bxK Fitness: 6.956521739130435
# String: BNaUpardO, turda da mC! Fitness: 6.521739130434782
# String: Boa tavdO,Atnrda dp mAt Fitness: 6.521739130434782
# Solução encontrada

# %%
# import random
# import string

# alfabeto = " abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!.,"


# class Agent:
#     def __init__(self, length):
#         self.string = ''.join(random.choice(alfabeto) for _ in range(length))
#         self.fitness = -1
#     def __str__(self):
#         return ('String: ' + str(self.string) + ' Fitness: ' + str(self.fitness))

# in_str = None
# in_str_len = None
# populacao = 30
# geracoes = 1000


# def ga():
#     agents = init_agents(populacao, in_str_len)
#     for geracao in range(geracoes):
#         print('Geração: ' + str(geracao))
#         agents = fitness(agents)
#         agents = selecao(agents)
#         agents = crossover(agents)
#         agents = mutacao(agents)
#         if any(agent.fitness >= 10.0 for agent in agents):
#             print('Solução encontrada')
#             break


# def init_agents(populacao, length):
#     print(Agent(length) for _ in range(populacao))
#     return [Agent(length) for _ in range(populacao)]

# def get_fitness(string, target):
#     points = sum(1 for expected, actual in zip(target, string) if expected == actual)
#     return ((points*10)/in_str_len)

# def fitness(agents):
#     for agent in agents:
#         agent.fitness = get_fitness(agent.string, in_str)
#     return agents


# def selecao(agents):
#     agents = sorted(agents, key=lambda agent: agent.fitness, reverse=True)
#     print('\n'.join(map(str, agents)))
#     agents = agents[:int(0.2 * len(agents))]
#     return agents


# def crossover(agents):
#     offspring = []
#     for _ in range(int((populacao - len(agents) / 2))):
#         pai1 = random.choice(agents)
#         pai2 = random.choice(agents)
#         filho1 = Agent(in_str_len)
#         filho2 = Agent(in_str_len)
#         split = random.randint(0, in_str_len)
#         filho1.string = pai1.string[0:split] + pai2.string[split:in_str_len]
#         filho2.string = pai2.string[0:split] + pai1.string[split:in_str_len]
#         offspring.append(filho1)
#         offspring.append(filho2)
#     agents.extend(offspring)
#     return agents


# def mutacao(agents):
#     for agent in agents:
#         for idx, param in enumerate(agent.string):
#             if random.uniform(0.0, 1.0) <= 0.1:
#                 agent.string = agent.string[0:idx] + random.choice(alfabeto) + agent.string[idx+1:in_str_len]
#     return agents


# if __name__ == '__main__':
#     in_str = 'Boa tarde, turma de IA!'
#     in_str_len = len(in_str)
#     ga()
